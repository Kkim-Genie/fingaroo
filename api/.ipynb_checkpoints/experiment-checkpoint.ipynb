# %%
from app.agent.graphs.main_agent import main_agent
from app.utils.langgraph import visualize_graph

graph_app = main_agent()
visualize_graph(graph_app)
# Out:
# Running cells with 'Python 3.13.5' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
from app.consts import Consts
from app.agent.states.basic_state import GraphState
from langchain_core.runnables import RunnableConfig
from app.utils.langgraph import random_uuid
from langchain_core.messages import HumanMessage, SystemMessage
from app.utils.langgraph import print_graph

inputs = GraphState(
    messages=[
        SystemMessage(content=Consts.SYSTEM_PROMPT),
        HumanMessage(content="현재 애플의 주가를 알려줘"),
    ],
    remaining_steps=25,
    is_last_step=False,
)
config = RunnableConfig(recursion_limit=6, configurable={"thread_id": random_uuid()})

await print_graph(graph_app, dict(inputs), config, isPrintAll=True)
# Out:
#  ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# ----
# supervisor ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# ----
# supervisor ( messages )
# (AIMessageChunk(content='', additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []}, id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da', tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}], usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}, tool_call_chunks=[{'name': 'transfer_to_stock_price_agent', 'args': '{}', 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'index': None, 'type': 'tool_call_chunk'}]), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'supervisor:8c889aef-4095-1412-3bc2-140c24f3f7b8|agent:7428ee69-e71f-d497-0899-2740d71791c2', 'checkpoint_ns': 'supervisor:8c889aef-4095-1412-3bc2-140c24f3f7b8', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# supervisor ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# ----
#  ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# ----
# stock_price_agent ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# ----
# stock_price_agent ( messages )
# (AIMessageChunk(content='', additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []}, id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903', tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}], usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}, tool_call_chunks=[{'name': 'search_indicator_id_tool', 'args': '{"symbol": "apple"}', 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'index': None, 'type': 'tool_call_chunk'}]), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|agent:781310a5-7056-eaed-c257-a4887f3178c7', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# stock_price_agent ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# ----
# stock_price_agent ( messages )
# (ToolMessage(content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>", name='search_indicator_id_tool', id='5e88e68a-c2b3-4d96-8699-e95d91ee3834', tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|tools:a913540b-1945-f072-a659-5204fd207f2b', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da'})
# ----
# stock_price_agent ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# ----
# stock_price_agent ( messages )
# (AIMessageChunk(content='', additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []}, id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed', tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}, tool_call_chunks=[{'name': 'search_stock_price_tool', 'args': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}', 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'index': None, 'type': 'tool_call_chunk'}]), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 3, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|agent:f4a4b746-fb82-8682-ad05-3d28d0910b48', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# stock_price_agent ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# content='' additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed' tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}
# ----
# stock_price_agent ( messages )
# (ToolMessage(content="<stock_price_result>[{'date': '2025-07-07', 'value': 210.0099945}, {'date': '2025-07-06', 'value': 209.95}, {'date': '2025-07-02', 'value': 213.55}, {'date': '2025-07-01', 'value': 212.44}]</stock_price_result>", name='search_stock_price_tool', id='d30bc02a-7078-4a28-ad6b-1721d78be552', tool_call_id='3a240b27-f8a8-435b-a9b6-3532acc49b41'), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 4, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|tools:bd960296-69d5-2585-7779-f0ee8ef3ffb9', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da'})
# ----
# stock_price_agent ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# content='' additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed' tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}
# content="<stock_price_result>[{'date': '2025-07-07', 'value': 210.0099945}, {'date': '2025-07-06', 'value': 209.95}, {'date': '2025-07-02', 'value': 213.55}, {'date': '2025-07-01', 'value': 212.44}]</stock_price_result>" name='search_stock_price_tool' id='d30bc02a-7078-4a28-ad6b-1721d78be552' tool_call_id='3a240b27-f8a8-435b-a9b6-3532acc49b41'
# ----
# stock_price_agent ( messages )
# (AIMessageChunk(content='애', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d', usage_metadata={'input_tokens': 1561, 'output_tokens': 1, 'total_tokens': 1562, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 5, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|agent:cd2be2c3-c06a-f503-7f5b-774baf83e2bd', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# stock_price_agent ( messages )
# (AIMessageChunk(content='플의 최근 주가는 다음과 같습니다.\n\n*   2025-', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d', usage_metadata={'input_tokens': 0, 'output_tokens': 16, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 5, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|agent:cd2be2c3-c06a-f503-7f5b-774baf83e2bd', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# stock_price_agent ( messages )
# (AIMessageChunk(content='07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: ', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d', usage_metadata={'input_tokens': 0, 'output_tokens': 48, 'total_tokens': 48, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 5, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|agent:cd2be2c3-c06a-f503-7f5b-774baf83e2bd', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# stock_price_agent ( messages )
# (AIMessageChunk(content='213.55\n*   2025-07-01: 212.44', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []}, id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d', usage_metadata={'input_tokens': 0, 'output_tokens': 27, 'total_tokens': 27, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 5, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da|agent:cd2be2c3-c06a-f503-7f5b-774baf83e2bd', 'checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# stock_price_agent ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# content='' additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed' tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}
# content="<stock_price_result>[{'date': '2025-07-07', 'value': 210.0099945}, {'date': '2025-07-06', 'value': 209.95}, {'date': '2025-07-02', 'value': 213.55}, {'date': '2025-07-01', 'value': 212.44}]</stock_price_result>" name='search_stock_price_tool' id='d30bc02a-7078-4a28-ad6b-1721d78be552' tool_call_id='3a240b27-f8a8-435b-a9b6-3532acc49b41'
# content='애플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.55\n*   2025-07-01: 212.44' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17'} name='stock_price_agent' id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d' usage_metadata={'input_tokens': 1561, 'output_tokens': 92, 'total_tokens': 1653, 'input_token_details': {'cache_read': 0}}
# ----
# stock_price_agent ( messages )
# (AIMessage(content='Transferring back to supervisor', additional_kwargs={}, response_metadata={'__is_handoff_back': True}, name='stock_price_agent', id='83fac230-5ba9-4946-bdb5-e4379297329b', tool_calls=[{'name': 'transfer_back_to_supervisor', 'args': {}, 'id': '4900ff05-3605-4458-9e5d-f811ce10acde', 'type': 'tool_call'}]), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 2, 'langgraph_node': 'stock_price_agent', 'langgraph_triggers': ('branch:to:stock_price_agent',), 'langgraph_path': ('__pregel_pull', 'stock_price_agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da'})
# ----
# stock_price_agent ( messages )
# (ToolMessage(content='Successfully transferred back to supervisor', name='transfer_back_to_supervisor', id='347e2434-5a50-4d3f-b4f8-601bbf07b8b1', tool_call_id='4900ff05-3605-4458-9e5d-f811ce10acde'), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 2, 'langgraph_node': 'stock_price_agent', 'langgraph_triggers': ('branch:to:stock_price_agent',), 'langgraph_path': ('__pregel_pull', 'stock_price_agent'), 'langgraph_checkpoint_ns': 'stock_price_agent:16b04c40-073f-82d5-c750-42dad397c2da'})
# ----
#  ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# content='' additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed' tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}
# content="<stock_price_result>[{'date': '2025-07-07', 'value': 210.0099945}, {'date': '2025-07-06', 'value': 209.95}, {'date': '2025-07-02', 'value': 213.55}, {'date': '2025-07-01', 'value': 212.44}]</stock_price_result>" name='search_stock_price_tool' id='d30bc02a-7078-4a28-ad6b-1721d78be552' tool_call_id='3a240b27-f8a8-435b-a9b6-3532acc49b41'
# content='애플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.55\n*   2025-07-01: 212.44' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17'} name='stock_price_agent' id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d' usage_metadata={'input_tokens': 1561, 'output_tokens': 92, 'total_tokens': 1653, 'input_token_details': {'cache_read': 0}}
# content='Transferring back to supervisor' additional_kwargs={} response_metadata={'__is_handoff_back': True} name='stock_price_agent' id='83fac230-5ba9-4946-bdb5-e4379297329b' tool_calls=[{'name': 'transfer_back_to_supervisor', 'args': {}, 'id': '4900ff05-3605-4458-9e5d-f811ce10acde', 'type': 'tool_call'}]
# content='Successfully transferred back to supervisor' name='transfer_back_to_supervisor' id='347e2434-5a50-4d3f-b4f8-601bbf07b8b1' tool_call_id='4900ff05-3605-4458-9e5d-f811ce10acde'
# ----
# supervisor ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# content='' additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed' tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}
# content="<stock_price_result>[{'date': '2025-07-07', 'value': 210.0099945}, {'date': '2025-07-06', 'value': 209.95}, {'date': '2025-07-02', 'value': 213.55}, {'date': '2025-07-01', 'value': 212.44}]</stock_price_result>" name='search_stock_price_tool' id='d30bc02a-7078-4a28-ad6b-1721d78be552' tool_call_id='3a240b27-f8a8-435b-a9b6-3532acc49b41'
# content='애플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.55\n*   2025-07-01: 212.44' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17'} name='stock_price_agent' id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d' usage_metadata={'input_tokens': 1561, 'output_tokens': 92, 'total_tokens': 1653, 'input_token_details': {'cache_read': 0}}
# content='Transferring back to supervisor' additional_kwargs={} response_metadata={'__is_handoff_back': True} name='stock_price_agent' id='83fac230-5ba9-4946-bdb5-e4379297329b' tool_calls=[{'name': 'transfer_back_to_supervisor', 'args': {}, 'id': '4900ff05-3605-4458-9e5d-f811ce10acde', 'type': 'tool_call'}]
# content='Successfully transferred back to supervisor' name='transfer_back_to_supervisor' id='347e2434-5a50-4d3f-b4f8-601bbf07b8b1' tool_call_id='4900ff05-3605-4458-9e5d-f811ce10acde'
# ----
# supervisor ( messages )
# (AIMessageChunk(content='애', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--59b13c6b-cc82-4985-a64f-d2b9147944f1', usage_metadata={'input_tokens': 1566, 'output_tokens': 1, 'total_tokens': 1567, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57|agent:17d0e079-a47d-833f-e5f7-a6ec13bda842', 'checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# supervisor ( messages )
# (AIMessageChunk(content='플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--59b13c6b-cc82-4985-a64f-d2b9147944f1', usage_metadata={'input_tokens': 0, 'output_tokens': 21, 'total_tokens': 21, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57|agent:17d0e079-a47d-833f-e5f7-a6ec13bda842', 'checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# supervisor ( messages )
# (AIMessageChunk(content=': 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.', additional_kwargs={}, response_metadata={'safety_ratings': []}, id='run--59b13c6b-cc82-4985-a64f-d2b9147944f1', usage_metadata={'input_tokens': 0, 'output_tokens': 48, 'total_tokens': 48, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57|agent:17d0e079-a47d-833f-e5f7-a6ec13bda842', 'checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# supervisor ( messages )
# (AIMessageChunk(content='55\n*   2025-07-01: 212.44', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []}, id='run--59b13c6b-cc82-4985-a64f-d2b9147944f1', usage_metadata={'input_tokens': 0, 'output_tokens': 23, 'total_tokens': 23, 'input_token_details': {'cache_read': 0}}), {'thread_id': '4c1b1628-12bf-41bc-ad0e-e2f58f7c836f', 'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57|agent:17d0e079-a47d-833f-e5f7-a6ec13bda842', 'checkpoint_ns': 'supervisor:2bd8e9c2-2551-6f99-dac1-518f4cdf9c57', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash-lite-preview-06-17', 'ls_model_type': 'chat', 'ls_temperature': 0.7})
# ----
# supervisor ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# content='' additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed' tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}
# content="<stock_price_result>[{'date': '2025-07-07', 'value': 210.0099945}, {'date': '2025-07-06', 'value': 209.95}, {'date': '2025-07-02', 'value': 213.55}, {'date': '2025-07-01', 'value': 212.44}]</stock_price_result>" name='search_stock_price_tool' id='d30bc02a-7078-4a28-ad6b-1721d78be552' tool_call_id='3a240b27-f8a8-435b-a9b6-3532acc49b41'
# content='애플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.55\n*   2025-07-01: 212.44' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17'} name='stock_price_agent' id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d' usage_metadata={'input_tokens': 1561, 'output_tokens': 92, 'total_tokens': 1653, 'input_token_details': {'cache_read': 0}}
# content='Transferring back to supervisor' additional_kwargs={} response_metadata={'__is_handoff_back': True} name='stock_price_agent' id='83fac230-5ba9-4946-bdb5-e4379297329b' tool_calls=[{'name': 'transfer_back_to_supervisor', 'args': {}, 'id': '4900ff05-3605-4458-9e5d-f811ce10acde', 'type': 'tool_call'}]
# content='Successfully transferred back to supervisor' name='transfer_back_to_supervisor' id='347e2434-5a50-4d3f-b4f8-601bbf07b8b1' tool_call_id='4900ff05-3605-4458-9e5d-f811ce10acde'
# content='애플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.55\n*   2025-07-01: 212.44' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17'} name='supervisor' id='run--59b13c6b-cc82-4985-a64f-d2b9147944f1' usage_metadata={'input_tokens': 1566, 'output_tokens': 93, 'total_tokens': 1659, 'input_token_details': {'cache_read': 0}}
# ----
#  ( values )
# content='\n    당신은 금융 정보 분석 조수이고 이름은 한글로 핀구, 영어로 Fingoo입니다.\n    오늘의 날짜: 2025-07-09\n    ' additional_kwargs={} response_metadata={} id='c3674e40-c254-44ce-ba47-938a2c272a53'
# content='현재 애플의 주가를 알려줘' additional_kwargs={} response_metadata={} id='f6471427-fb32-4f06-83aa-13df721abb14'
# content='' additional_kwargs={'function_call': {'name': 'transfer_to_stock_price_agent', 'arguments': '{}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='supervisor' id='run--28f0dba6-cd2a-4788-84a3-d6c9091c78da' tool_calls=[{'name': 'transfer_to_stock_price_agent', 'args': {}, 'id': '54f71ab2-5599-4395-83aa-fc75ab13988b', 'type': 'tool_call'}] usage_metadata={'input_tokens': 635, 'output_tokens': 16, 'total_tokens': 651, 'input_token_details': {'cache_read': 0}}
# content='Successfully transferred to stock_price_agent' name='transfer_to_stock_price_agent' id='2594e8f8-b7a5-4016-b4c7-45fd4c34f1df' tool_call_id='54f71ab2-5599-4395-83aa-fc75ab13988b'
# content='' additional_kwargs={'function_call': {'name': 'search_indicator_id_tool', 'arguments': '{"symbol": "apple"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--f6343bf5-25e2-4a34-acec-7f09bfbc2903' tool_calls=[{'name': 'search_indicator_id_tool', 'args': {'symbol': 'apple'}, 'id': '01e82360-ca02-4ba5-b11f-b83c0635eb52', 'type': 'tool_call'}] usage_metadata={'input_tokens': 805, 'output_tokens': 19, 'total_tokens': 824, 'input_token_details': {'cache_read': 0}}
# content="<indicator_search_result>[{'id': 'e95842c0-e646-4d9b-aedc-7ebbf40944ae', 'index': 46, 'indicatorType': 'stock', 'symbol': 'AAPI', 'name': 'Apple Isport Group Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'OTC', 'micCode': 'PINX', 'figiCode': 'BBG000CQPMH4', 'type': 'Common Stock'}, {'id': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'index': 48, 'indicatorType': 'stock', 'symbol': 'AAPL', 'name': 'Apple Inc.', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NASDAQ', 'micCode': 'XNGS', 'figiCode': 'BBG000B9Y5X2', 'type': 'Common Stock'}, {'id': '497ede25-02df-4082-a5cf-ac42f64f760c', 'index': 51, 'indicatorType': 'stock', 'symbol': 'AAPX', 'name': 'T-REX 2X Liquid Natural Gas Apple Daily Target Fund', 'unit': 'USD', 'country': 'United States', 'currency': 'USD', 'exchange': 'NYSE', 'micCode': 'XNYS', 'figiCode': 'BBG01KY72SJ7', 'type': 'Common Stock'}]</indicator_search_result>" name='search_indicator_id_tool' id='5e88e68a-c2b3-4d96-8699-e95d91ee3834' tool_call_id='01e82360-ca02-4ba5-b11f-b83c0635eb52'
# content='' additional_kwargs={'function_call': {'name': 'search_stock_price_tool', 'arguments': '{"endDate": "2025-07-09", "indicatorId": "4c0a09dd-0d31-48a8-9a0a-4c9de031a644", "startDate": "2025-07-02", "interval": "day", "dataAggregation": "eop", "indicatorType": "stock"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17', 'safety_ratings': []} name='stock_price_agent' id='run--75274c6c-5c18-4d41-9ba7-4b27a39ea0ed' tool_calls=[{'name': 'search_stock_price_tool', 'args': {'endDate': '2025-07-09', 'indicatorId': '4c0a09dd-0d31-48a8-9a0a-4c9de031a644', 'startDate': '2025-07-02', 'interval': 'day', 'dataAggregation': 'eop', 'indicatorType': 'stock'}, 'id': '3a240b27-f8a8-435b-a9b6-3532acc49b41', 'type': 'tool_call'}] usage_metadata={'input_tokens': 1307, 'output_tokens': 99, 'total_tokens': 1406, 'input_token_details': {'cache_read': 0}}
# content="<stock_price_result>[{'date': '2025-07-07', 'value': 210.0099945}, {'date': '2025-07-06', 'value': 209.95}, {'date': '2025-07-02', 'value': 213.55}, {'date': '2025-07-01', 'value': 212.44}]</stock_price_result>" name='search_stock_price_tool' id='d30bc02a-7078-4a28-ad6b-1721d78be552' tool_call_id='3a240b27-f8a8-435b-a9b6-3532acc49b41'
# content='애플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.55\n*   2025-07-01: 212.44' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17'} name='stock_price_agent' id='run--a9b3f287-f1e8-47ca-91a2-169d9d9df67d' usage_metadata={'input_tokens': 1561, 'output_tokens': 92, 'total_tokens': 1653, 'input_token_details': {'cache_read': 0}}
# content='Transferring back to supervisor' additional_kwargs={} response_metadata={'__is_handoff_back': True} name='stock_price_agent' id='83fac230-5ba9-4946-bdb5-e4379297329b' tool_calls=[{'name': 'transfer_back_to_supervisor', 'args': {}, 'id': '4900ff05-3605-4458-9e5d-f811ce10acde', 'type': 'tool_call'}]
# content='Successfully transferred back to supervisor' name='transfer_back_to_supervisor' id='347e2434-5a50-4d3f-b4f8-601bbf07b8b1' tool_call_id='4900ff05-3605-4458-9e5d-f811ce10acde'
# content='애플의 최근 주가는 다음과 같습니다.\n\n*   2025-07-07: 210.01\n*   2025-07-06: 209.95\n*   2025-07-02: 213.55\n*   2025-07-01: 212.44' additional_kwargs={} response_metadata={'safety_ratings': [], 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite-preview-06-17'} name='supervisor' id='run--59b13c6b-cc82-4985-a64f-d2b9147944f1' usage_metadata={'input_tokens': 1566, 'output_tokens': 93, 'total_tokens': 1659, 'input_token_details': {'cache_read': 0}}
# ----
